# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\MAINGATE\\Desktop\\Maize_disease_classification\\end-to-end_mazie_disease_classification\\research'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'c:\\Users\\MAINGATE\\Desktop\\Maize_disease_classification\\end-to-end_mazie_disease_classification'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class PrepareBaseModelConfig:
    root_dir: Path
    base_model_path: Path
    params_image_size: tuple
    params_learning_rate: float
    params_alpha: float
    params_beta: float
    params_classes: int

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories
import ast

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath= CONFIG_FILE_PATH,
        params_filepath= PARAMS_FILE_PATH):

        self.config= read_yaml(config_filepath)
        self.params= read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_prepare_base_model_config(self) -> PrepareBaseModelConfig:

        config= self.config.prepare_base_model

        create_directories([config.root_dir])

        prepare_base_model_config= PrepareBaseModelConfig(
            root_dir= Path(config.root_dir),
            base_model_path= Path(config.base_model_path),
            params_image_size= ast.literal_eval(self.params.IMAGE_SIZE),
            params_classes= self.params.CLASSES,
            params_alpha= self.params.alpha,
            params_beta=self.params.beta,
            params_learning_rate= self.params.LEARNING_RATE
        )

        return  prepare_base_model_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
print(tf.__file__)
# Out:
# c:\Users\MAINGATE\.conda\envs\maize\lib\site-packages\tensorflow\__init__.py

# %%
import tf_keras

import numpy as np
from tf_keras import layers as Layers
from tf_keras import Model

# %%
from tf_keras.src.optimizers import Adam
from tf_keras.losses import CategoricalCrossentropy

# %%
class PrepareBaseModel:
    def __init__(self, config: PrepareBaseModelConfig):
        self.config = config
        #self.alpha = config.alpha
        #self.beta = config.beta
        self.model = self.build_model()
        self.compile_model()
        self.model.summary()  # Print model architecture after compilation


    def DMA_Block(self, x, dilation_rate=1):
        """Dilated Module Attention Block with skip connection.
     1. Applies dialated convolution to enlarge the receptive field without downsamplling(this captures multiscale features )
     2. Add the result back to the original input ( preserves the original image and prevents degradaton in deeper network)"""
    
        skip = x
        x = Layers.Conv2D(filters=x.shape[-1], kernel_size=3, padding='same',
                          dilation_rate=dilation_rate, use_bias=False)(x)
        x = Layers.BatchNormalization()(x)
        x = Layers.ReLU()(x)
        return Layers.add([x, skip])

    def PMFFM(self, x):
        """Parallel Multi-scale Feature Fusion Module.
      1.Sends input through 3 DMA blocks, each with a different dilation rate.
      2. Simulates multi-scale context aggregation, where each branch focuses on a different neighborhood size.

"""
        b1 = self.DMA_Block(x, dilation_rate=1)
        b2 = self.DMA_Block(x, dilation_rate=2)
        b3 = self.DMA_Block(x, dilation_rate=3)
        return Layers.add([b1, b2, b3])

    def PPA_Block(self, x, n=4):
        """Partial Pooling Attention Block.
      1. Most of the channels are kept at it is while the rest are average pooled(to reduce operational cost)
      2. Capture local content and reduce noise
      3. Guide the network to focus on spatial patterns"""
        
        c = x.shape[-1] 
        split = c // n
        keep_tensor = x[..., :c - split]
        pool_tensor = x[..., c - split:]
        pooled = Layers.AveragePooling2D(pool_size=3, strides=1, padding='same')(pool_tensor)
        return Layers.Concatenate()([keep_tensor, pooled])

        

    def MSA_Block(self, x, block_idx=1):
       """Multi-Scale Attention Block."""

       b1 = Layers.AveragePooling2D(pool_size=3, strides=1, padding='same')(x)
       b1 = Layers.Conv2D(x.shape[-1], 1, padding='same')(b1)
       b1 = Layers.ReLU()(b1)
       b1 = Layers.Conv2D(x.shape[-1], 1, padding='same')(b1)
       b1 = Layers.Activation('sigmoid')(b1)

       b2 = Layers.MaxPooling2D(pool_size=5, strides=1, padding='same')(x)
       b2 = Layers.Conv2D(x.shape[-1], 1, padding='same')(b2)
       b2 = Layers.ReLU()(b2)
       b2 = Layers.Conv2D(x.shape[-1], 1, padding='same')(b2)
       b2 = Layers.Activation('sigmoid')(b2)

       b3 = Layers.Conv2D(x.shape[-1], 1, padding='same')(x)
       b3 = Layers.ReLU()(b3)
       b3 = Layers.Conv2D(x.shape[-1], 1, padding='same')(b3)
       b3 = Layers.Activation('sigmoid')(b3)

           # Manually combine the results using the scaling factors without a Lambda layer
       combined = self.config.params_alpha * b1 + \
              (1 - self.config.params_alpha - self.config.params_beta) * b2 + \
              self.config.params_beta * b3

        # Return the product of the input 'x' and the weighted sum of b1, b2, b3
       return Layers.Multiply()([x, combined])



    def MAttion_block(self, x, filters, block_idx):
        """MAttion block that combines pooling, attention, and convolutions.
    
       1. Combines multi-scale feature extraction, channel-wise filtering, and attention weighting in one block.
       2. Helps the model focus and adapt its attention spatially and across channels.

"""

        x = Layers.Conv2D(filters, 1, padding='same')(x)
        x = Layers.BatchNormalization()(x)
        x = Layers.ReLU()(x)

        k = 3 + 2 * block_idx
        x = Layers.MaxPooling2D(pool_size=k, strides=2, padding="same")(x)

        x = self.PPA_Block(x)
        x = self.MSA_Block(x, block_idx)

        x = Layers.Conv2D(filters, 1, padding="same")(x)
        x = Layers.BatchNormalization()(x)
        x = Layers.ReLU()(x)

        x = Layers.Conv2D(filters, 3, padding="same")(x)
        x = Layers.ReLU()(x)

        return x

    def build_model(self):
        """LFMNet architecture for classification."""
        inputs = Layers.Input(shape=self.config.params_image_size)

        x = Layers.Conv2D(24, 7, strides=2, padding='same')(inputs)
        x = Layers.BatchNormalization()(x)
        x = Layers.ReLU()(x)
        x = Layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

        x = self.PMFFM(x)
        x = self.MAttion_block(x, filters=48, block_idx=1)

        x = self.PMFFM(x)
        x = self.MAttion_block(x, filters=96, block_idx=2)

        x = self.MAttion_block(x, filters=192, block_idx=3)
        x = self.MAttion_block(x, filters=256, block_idx=4)

        x = Layers.GlobalAveragePooling2D()(x)
        outputs = Layers.Dense(self.config.params_classes, activation='softmax')(x)

        return Model(inputs, outputs, name="LFMNet")

    def compile_model(self):
        self.model.compile(
            # Instantiate the Adam optimizer with only the learning_rate specified
            #optimizer = Adam(learning_rate=0.001)  # Only specify the learning rate

            optimizer=Adam(learning_rate=self.config.params_learning_rate),
            loss=CategoricalCrossentropy(),
            metrics=['accuracy']
        )
        self.model.summary()
        return self.model
    
    def save_model(self, h5=False, use_legacy=False):
        """
        Save the model in .h5, SavedModel or legacy format.
        """
        if use_legacy:
            from tf_keras.src.saving.legacy.saved_model.save import save as legacy_save

            path = str(self.config.base_model_path.with_suffix(''))  # Remove .h5 suffix if any
            legacy_save(
            model=self.model,
            filepath=path,
            overwrite=True,
            include_optimizer=True
            )
            print(f"Model saved using legacy internal API at {path}")


        if h5:
            h5_path = self.config.base_model_path.with_suffix(".h5")
            self.model.save(h5_path, save_format='h5')
            print(f" Model saved in HDF5 format to {h5_path}")
        else:
            tf_path = str(self.config.base_model_path)
            self.model.save(tf_path, save_format='tf')
            print(f" Model saved in TensorFlow SavedModel format to {tf_path}")

# %%
try:
    config= ConfigurationManager()
    prepare_base_model_config= config.get_prepare_base_model_config()
    prepare_base_model=PrepareBaseModel(config=prepare_base_model_config)
    prepare_base_model.compile_model()
    prepare_base_model.save_model(use_legacy=True)

except Exception as e:
    raise e
# Out:
# [2025-04-26 07:39:16,533: INFO: common: yaml file: (path_to_yaml) loaded successfully]
# [2025-04-26 07:39:16,548: INFO: common: yaml file: (path_to_yaml) loaded successfully]
# [2025-04-26 07:39:16,562: INFO: common: created a directory at : artifacts]
# [2025-04-26 07:39:16,575: INFO: common: created a directory at : artifacts/prepare_base_model]
# Model: "LFMNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 24)         3552      ['input_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 112, 112, 24)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 112, 112, 24)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 24)           0         ['re_lu_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 24)           5184      ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 24)           5184      ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 24)           5184      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 24)           96        ['conv2d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 56, 56, 24)           96        ['conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 56, 56, 24)           96        ['conv2d_4[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 56, 56, 24)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  re_lu_3 (ReLU)              (None, 56, 56, 24)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  re_lu_4 (ReLU)              (None, 56, 56, 24)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 56, 56, 24)           0         ['re_lu_2[0][0]',
#                                                                      'max_pooling2d_1[0][0]']
#
#  add_1 (Add)                 (None, 56, 56, 24)           0         ['re_lu_3[0][0]',
#                                                                      'max_pooling2d_1[0][0]']
#
#  add_2 (Add)                 (None, 56, 56, 24)           0         ['re_lu_4[0][0]',
#                                                                      'max_pooling2d_1[0][0]']
#
#  add_3 (Add)                 (None, 56, 56, 24)           0         ['add[0][0]',
#                                                                      'add_1[0][0]',
#                                                                      'add_2[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 48)           1200      ['add_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 56, 56, 48)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 56, 56, 48)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 48)           0         ['re_lu_5[0][0]']
#  g2D)
#
#  tf.__operators__.getitem_1  (None, 28, 28, 12)           0         ['max_pooling2d_2[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem (  (None, 28, 28, 36)           0         ['max_pooling2d_2[0][0]']
#  SlicingOpLambda)
#
#  average_pooling2d (Average  (None, 28, 28, 12)           0         ['tf.__operators__.getitem_1[0
#  Pooling2D)                                                         ][0]']
#
#  concatenate (Concatenate)   (None, 28, 28, 48)           0         ['tf.__operators__.getitem[0][
#                                                                     0]',
#                                                                      'average_pooling2d[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 28, 28, 48)           0         ['concatenate[0][0]']
#  gePooling2D)
#
#  max_pooling2d_3 (MaxPoolin  (None, 28, 28, 48)           0         ['concatenate[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 48)           2352      ['average_pooling2d_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 48)           2352      ['max_pooling2d_3[0][0]']
#
#  re_lu_6 (ReLU)              (None, 28, 28, 48)           0         ['conv2d_6[0][0]']
#
#  re_lu_7 (ReLU)              (None, 28, 28, 48)           0         ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 48)           2352      ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 48)           2352      ['re_lu_6[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 48)           2352      ['re_lu_7[0][0]']
#
#  re_lu_8 (ReLU)              (None, 28, 28, 48)           0         ['conv2d_10[0][0]']
#
#  activation (Activation)     (None, 28, 28, 48)           0         ['conv2d_7[0][0]']
#
#  activation_1 (Activation)   (None, 28, 28, 48)           0         ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 48)           2352      ['re_lu_8[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 28, 28, 48)           0         ['activation[0][0]']
#  da)
#
#  tf.math.multiply_1 (TFOpLa  (None, 28, 28, 48)           0         ['activation_1[0][0]']
#  mbda)
#
#  activation_2 (Activation)   (None, 28, 28, 48)           0         ['conv2d_11[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 28, 28, 48)           0         ['tf.math.multiply[0][0]',
#  Lambda)                                                             'tf.math.multiply_1[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 28, 28, 48)           0         ['activation_2[0][0]']
#  mbda)
#
#  tf.__operators__.add_1 (TF  (None, 28, 28, 48)           0         ['tf.__operators__.add[0][0]',
#  OpLambda)                                                           'tf.math.multiply_2[0][0]']
#
#  multiply (Multiply)         (None, 28, 28, 48)           0         ['concatenate[0][0]',
#                                                                      'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 48)           2352      ['multiply[0][0]']
#
#  batch_normalization_6 (Bat  (None, 28, 28, 48)           192       ['conv2d_12[0][0]']
#  chNormalization)
#
#  re_lu_9 (ReLU)              (None, 28, 28, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 48)           20784     ['re_lu_9[0][0]']
#
#  re_lu_10 (ReLU)             (None, 28, 28, 48)           0         ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 48)           20736     ['re_lu_10[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 48)           20736     ['re_lu_10[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 48)           20736     ['re_lu_10[0][0]']
#
#  batch_normalization_7 (Bat  (None, 28, 28, 48)           192       ['conv2d_14[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 28, 28, 48)           192       ['conv2d_15[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 28, 28, 48)           192       ['conv2d_16[0][0]']
#  chNormalization)
#
#  re_lu_11 (ReLU)             (None, 28, 28, 48)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  re_lu_12 (ReLU)             (None, 28, 28, 48)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  re_lu_13 (ReLU)             (None, 28, 28, 48)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  add_4 (Add)                 (None, 28, 28, 48)           0         ['re_lu_11[0][0]',
#                                                                      're_lu_10[0][0]']
#
#  add_5 (Add)                 (None, 28, 28, 48)           0         ['re_lu_12[0][0]',
#                                                                      're_lu_10[0][0]']
#
#  add_6 (Add)                 (None, 28, 28, 48)           0         ['re_lu_13[0][0]',
#                                                                      're_lu_10[0][0]']
#
#  add_7 (Add)                 (None, 28, 28, 48)           0         ['add_4[0][0]',
#                                                                      'add_5[0][0]',
#                                                                      'add_6[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 96)           4704      ['add_7[0][0]']
#
#  batch_normalization_10 (Ba  (None, 28, 28, 96)           384       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 28, 28, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 96)           0         ['re_lu_14[0][0]']
#  g2D)
#
#  tf.__operators__.getitem_3  (None, 14, 14, 24)           0         ['max_pooling2d_4[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 14, 14, 72)           0         ['max_pooling2d_4[0][0]']
#   (SlicingOpLambda)
#
#  average_pooling2d_2 (Avera  (None, 14, 14, 24)           0         ['tf.__operators__.getitem_3[0
#  gePooling2D)                                                       ][0]']
#
#  concatenate_1 (Concatenate  (None, 14, 14, 96)           0         ['tf.__operators__.getitem_2[0
#  )                                                                  ][0]',
#                                                                      'average_pooling2d_2[0][0]']
#
#  average_pooling2d_3 (Avera  (None, 14, 14, 96)           0         ['concatenate_1[0][0]']
#  gePooling2D)
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 96)           0         ['concatenate_1[0][0]']
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 96)           9312      ['average_pooling2d_3[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 96)           9312      ['max_pooling2d_5[0][0]']
#
#  re_lu_15 (ReLU)             (None, 14, 14, 96)           0         ['conv2d_18[0][0]']
#
#  re_lu_16 (ReLU)             (None, 14, 14, 96)           0         ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 96)           9312      ['concatenate_1[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 96)           9312      ['re_lu_15[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 96)           9312      ['re_lu_16[0][0]']
#
#  re_lu_17 (ReLU)             (None, 14, 14, 96)           0         ['conv2d_22[0][0]']
#
#  activation_3 (Activation)   (None, 14, 14, 96)           0         ['conv2d_19[0][0]']
#
#  activation_4 (Activation)   (None, 14, 14, 96)           0         ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 96)           9312      ['re_lu_17[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  (None, 14, 14, 96)           0         ['activation_3[0][0]']
#  mbda)
#
#  tf.math.multiply_4 (TFOpLa  (None, 14, 14, 96)           0         ['activation_4[0][0]']
#  mbda)
#
#  activation_5 (Activation)   (None, 14, 14, 96)           0         ['conv2d_23[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 14, 14, 96)           0         ['tf.math.multiply_3[0][0]',
#  OpLambda)                                                           'tf.math.multiply_4[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  (None, 14, 14, 96)           0         ['activation_5[0][0]']
#  mbda)
#
#  tf.__operators__.add_3 (TF  (None, 14, 14, 96)           0         ['tf.__operators__.add_2[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_5[0][0]']
#
#  multiply_1 (Multiply)       (None, 14, 14, 96)           0         ['concatenate_1[0][0]',
#                                                                      'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 96)           9312      ['multiply_1[0][0]']
#
#  batch_normalization_11 (Ba  (None, 14, 14, 96)           384       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 14, 14, 96)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 96)           83040     ['re_lu_18[0][0]']
#
#  re_lu_19 (ReLU)             (None, 14, 14, 96)           0         ['conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 192)          18624     ['re_lu_19[0][0]']
#
#  batch_normalization_12 (Ba  (None, 14, 14, 192)          768       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 14, 14, 192)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, 7, 7, 192)            0         ['re_lu_20[0][0]']
#  g2D)
#
#  tf.__operators__.getitem_5  (None, 7, 7, 48)             0         ['max_pooling2d_6[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_4  (None, 7, 7, 144)            0         ['max_pooling2d_6[0][0]']
#   (SlicingOpLambda)
#
#  average_pooling2d_4 (Avera  (None, 7, 7, 48)             0         ['tf.__operators__.getitem_5[0
#  gePooling2D)                                                       ][0]']
#
#  concatenate_2 (Concatenate  (None, 7, 7, 192)            0         ['tf.__operators__.getitem_4[0
#  )                                                                  ][0]',
#                                                                      'average_pooling2d_4[0][0]']
#
#  average_pooling2d_5 (Avera  (None, 7, 7, 192)            0         ['concatenate_2[0][0]']
#  gePooling2D)
#
#  max_pooling2d_7 (MaxPoolin  (None, 7, 7, 192)            0         ['concatenate_2[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 7, 7, 192)            37056     ['average_pooling2d_5[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 7, 7, 192)            37056     ['max_pooling2d_7[0][0]']
#
#  re_lu_21 (ReLU)             (None, 7, 7, 192)            0         ['conv2d_27[0][0]']
#
#  re_lu_22 (ReLU)             (None, 7, 7, 192)            0         ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 7, 7, 192)            37056     ['concatenate_2[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 7, 7, 192)            37056     ['re_lu_21[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 7, 7, 192)            37056     ['re_lu_22[0][0]']
#
#  re_lu_23 (ReLU)             (None, 7, 7, 192)            0         ['conv2d_31[0][0]']
#
#  activation_6 (Activation)   (None, 7, 7, 192)            0         ['conv2d_28[0][0]']
#
#  activation_7 (Activation)   (None, 7, 7, 192)            0         ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 7, 7, 192)            37056     ['re_lu_23[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None, 7, 7, 192)            0         ['activation_6[0][0]']
#  mbda)
#
#  tf.math.multiply_7 (TFOpLa  (None, 7, 7, 192)            0         ['activation_7[0][0]']
#  mbda)
#
#  activation_8 (Activation)   (None, 7, 7, 192)            0         ['conv2d_32[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 7, 7, 192)            0         ['tf.math.multiply_6[0][0]',
#  OpLambda)                                                           'tf.math.multiply_7[0][0]']
#
#  tf.math.multiply_8 (TFOpLa  (None, 7, 7, 192)            0         ['activation_8[0][0]']
#  mbda)
#
#  tf.__operators__.add_5 (TF  (None, 7, 7, 192)            0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  multiply_2 (Multiply)       (None, 7, 7, 192)            0         ['concatenate_2[0][0]',
#                                                                      'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 7, 7, 192)            37056     ['multiply_2[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 7, 192)            768       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 7, 7, 192)            0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 7, 7, 192)            331968    ['re_lu_24[0][0]']
#
#  re_lu_25 (ReLU)             (None, 7, 7, 192)            0         ['conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 7, 7, 256)            49408     ['re_lu_25[0][0]']
#
#  batch_normalization_14 (Ba  (None, 7, 7, 256)            1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 7, 7, 256)            0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 256)            0         ['re_lu_26[0][0]']
#  g2D)
#
#  tf.__operators__.getitem_7  (None, 4, 4, 64)             0         ['max_pooling2d_8[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_6  (None, 4, 4, 192)            0         ['max_pooling2d_8[0][0]']
#   (SlicingOpLambda)
#
#  average_pooling2d_6 (Avera  (None, 4, 4, 64)             0         ['tf.__operators__.getitem_7[0
#  gePooling2D)                                                       ][0]']
#
#  concatenate_3 (Concatenate  (None, 4, 4, 256)            0         ['tf.__operators__.getitem_6[0
#  )                                                                  ][0]',
#                                                                      'average_pooling2d_6[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 4, 4, 256)            0         ['concatenate_3[0][0]']
#  gePooling2D)
#
#  max_pooling2d_9 (MaxPoolin  (None, 4, 4, 256)            0         ['concatenate_3[0][0]']
#  g2D)
#
#  conv2d_36 (Conv2D)          (None, 4, 4, 256)            65792     ['average_pooling2d_7[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 4, 4, 256)            65792     ['max_pooling2d_9[0][0]']
#
#  re_lu_27 (ReLU)             (None, 4, 4, 256)            0         ['conv2d_36[0][0]']
#
#  re_lu_28 (ReLU)             (None, 4, 4, 256)            0         ['conv2d_38[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 4, 4, 256)            65792     ['concatenate_3[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 4, 4, 256)            65792     ['re_lu_27[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 4, 4, 256)            65792     ['re_lu_28[0][0]']
#
#  re_lu_29 (ReLU)             (None, 4, 4, 256)            0         ['conv2d_40[0][0]']
#
#  activation_9 (Activation)   (None, 4, 4, 256)            0         ['conv2d_37[0][0]']
#
#  activation_10 (Activation)  (None, 4, 4, 256)            0         ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 4, 4, 256)            65792     ['re_lu_29[0][0]']
#
#  tf.math.multiply_9 (TFOpLa  (None, 4, 4, 256)            0         ['activation_9[0][0]']
#  mbda)
#
#  tf.math.multiply_10 (TFOpL  (None, 4, 4, 256)            0         ['activation_10[0][0]']
#  ambda)
#
#  activation_11 (Activation)  (None, 4, 4, 256)            0         ['conv2d_41[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 4, 4, 256)            0         ['tf.math.multiply_9[0][0]',
#  OpLambda)                                                           'tf.math.multiply_10[0][0]']
#
#  tf.math.multiply_11 (TFOpL  (None, 4, 4, 256)            0         ['activation_11[0][0]']
#  ambda)
#
#  tf.__operators__.add_7 (TF  (None, 4, 4, 256)            0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_11[0][0]']
#
#  multiply_3 (Multiply)       (None, 4, 4, 256)            0         ['concatenate_3[0][0]',
#                                                                      'tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 4, 4, 256)            65792     ['multiply_3[0][0]']
#
#  batch_normalization_15 (Ba  (None, 4, 4, 256)            1024      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 4, 4, 256)            0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 4, 4, 256)            590080    ['re_lu_30[0][0]']
#
#  re_lu_31 (ReLU)             (None, 4, 4, 256)            0         ['conv2d_43[0][0]']
#
#  global_average_pooling2d (  (None, 256)                  0         ['re_lu_31[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 3)                    771       ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 1989171 (7.59 MB)
# Trainable params: 1986323 (7.58 MB)
# Non-trainable params: 2848 (11.12 KB)
# __________________________________________________________________________________________________
# Model: "LFMNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 24)         3552      ['input_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 112, 112, 24)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 112, 112, 24)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 24)           0         ['re_lu_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 24)           5184      ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 24)           5184      ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 24)           5184      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 24)           96        ['conv2d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 56, 56, 24)           96        ['conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 56, 56, 24)           96        ['conv2d_4[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 56, 56, 24)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  re_lu_3 (ReLU)              (None, 56, 56, 24)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  re_lu_4 (ReLU)              (None, 56, 56, 24)           0         ['batch_normalization_4[0][0]'
# ...
#
#  average_pooling2d_5 (Avera  (None, 7, 7, 192)            0         ['concatenate_2[0][0]']
#  gePooling2D)
#
#  max_pooling2d_7 (MaxPoolin  (None, 7, 7, 192)            0         ['concatenate_2[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 7, 7, 192)            37056     ['average_pooling2d_5[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 7, 7, 192)            37056     ['max_pooling2d_7[0][0]']
#
#  re_lu_21 (ReLU)             (None, 7, 7, 192)            0         ['conv2d_27[0][0]']
#
#  re_lu_22 (ReLU)             (None, 7, 7, 192)            0         ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 7, 7, 192)            37056     ['concatenate_2[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 7, 7, 192)            37056     ['re_lu_21[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 7, 7, 192)            37056     ['re_lu_22[0][0]']
#
#  re_lu_23 (ReLU)             (None, 7, 7, 192)            0         ['conv2d_31[0][0]']
#
#  activation_6 (Activation)   (None, 7, 7, 192)            0         ['conv2d_28[0][0]']
#
#  activation_7 (Activation)   (None, 7, 7, 192)            0         ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 7, 7, 192)            37056     ['re_lu_23[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None, 7, 7, 192)            0         ['activation_6[0][0]']
#  mbda)
#
#  tf.math.multiply_7 (TFOpLa  (None, 7, 7, 192)            0         ['activation_7[0][0]']
#  mbda)
#
#  activation_8 (Activation)   (None, 7, 7, 192)            0         ['conv2d_32[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 7, 7, 192)            0         ['tf.math.multiply_6[0][0]',
#  OpLambda)                                                           'tf.math.multiply_7[0][0]']
#
#  tf.math.multiply_8 (TFOpLa  (None, 7, 7, 192)            0         ['activation_8[0][0]']
#  mbda)
#
#  tf.__operators__.add_5 (TF  (None, 7, 7, 192)            0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  multiply_2 (Multiply)       (None, 7, 7, 192)            0         ['concatenate_2[0][0]',
#                                                                      'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 7, 7, 192)            37056     ['multiply_2[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 7, 192)            768       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 7, 7, 192)            0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 7, 7, 192)            331968    ['re_lu_24[0][0]']
#
#  re_lu_25 (ReLU)             (None, 7, 7, 192)            0         ['conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 7, 7, 256)            49408     ['re_lu_25[0][0]']
#
#  batch_normalization_14 (Ba  (None, 7, 7, 256)            1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 7, 7, 256)            0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 256)            0         ['re_lu_26[0][0]']
#  g2D)
#
#  tf.__operators__.getitem_7  (None, 4, 4, 64)             0         ['max_pooling2d_8[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_6  (None, 4, 4, 192)            0         ['max_pooling2d_8[0][0]']
#   (SlicingOpLambda)
#
#  average_pooling2d_6 (Avera  (None, 4, 4, 64)             0         ['tf.__operators__.getitem_7[0
#  gePooling2D)                                                       ][0]']
#
#  concatenate_3 (Concatenate  (None, 4, 4, 256)            0         ['tf.__operators__.getitem_6[0
#  )                                                                  ][0]',
#                                                                      'average_pooling2d_6[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 4, 4, 256)            0         ['concatenate_3[0][0]']
#  gePooling2D)
#
#  max_pooling2d_9 (MaxPoolin  (None, 4, 4, 256)            0         ['concatenate_3[0][0]']
#  g2D)
#
#  conv2d_36 (Conv2D)          (None, 4, 4, 256)            65792     ['average_pooling2d_7[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 4, 4, 256)            65792     ['max_pooling2d_9[0][0]']
#
#  re_lu_27 (ReLU)             (None, 4, 4, 256)            0         ['conv2d_36[0][0]']
#
#  re_lu_28 (ReLU)             (None, 4, 4, 256)            0         ['conv2d_38[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 4, 4, 256)            65792     ['concatenate_3[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 4, 4, 256)            65792     ['re_lu_27[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 4, 4, 256)            65792     ['re_lu_28[0][0]']
#
#  re_lu_29 (ReLU)             (None, 4, 4, 256)            0         ['conv2d_40[0][0]']
#
#  activation_9 (Activation)   (None, 4, 4, 256)            0         ['conv2d_37[0][0]']
#
#  activation_10 (Activation)  (None, 4, 4, 256)            0         ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 4, 4, 256)            65792     ['re_lu_29[0][0]']
#
#  tf.math.multiply_9 (TFOpLa  (None, 4, 4, 256)            0         ['activation_9[0][0]']
#  mbda)
#
#  tf.math.multiply_10 (TFOpL  (None, 4, 4, 256)            0         ['activation_10[0][0]']
#  ambda)
#
#  activation_11 (Activation)  (None, 4, 4, 256)            0         ['conv2d_41[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 4, 4, 256)            0         ['tf.math.multiply_9[0][0]',
#  OpLambda)                                                           'tf.math.multiply_10[0][0]']
#
#  tf.math.multiply_11 (TFOpL  (None, 4, 4, 256)            0         ['activation_11[0][0]']
#  ambda)
#
#  tf.__operators__.add_7 (TF  (None, 4, 4, 256)            0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.math.multiply_11[0][0]']
#
#  multiply_3 (Multiply)       (None, 4, 4, 256)            0         ['concatenate_3[0][0]',
#                                                                      'tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 4, 4, 256)            65792     ['multiply_3[0][0]']
#
#  batch_normalization_15 (Ba  (None, 4, 4, 256)            1024      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 4, 4, 256)            0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 4, 4, 256)            590080    ['re_lu_30[0][0]']
#
#  re_lu_31 (ReLU)             (None, 4, 4, 256)            0         ['conv2d_43[0][0]']
#
#  global_average_pooling2d (  (None, 256)                  0         ['re_lu_31[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 3)                    771       ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 1989171 (7.59 MB)
# Trainable params: 1986323 (7.58 MB)
# Non-trainable params: 2848 (11.12 KB)
# __________________________________________________________________________________________________
# [2025-04-26 07:41:59,007: INFO: builder_impl: Assets written to: artifacts\prepare_base_model\base_model\assets]
# ✅ Model saved using legacy internal API at artifacts\prepare_base_model\base_model
# ✅ Model saved in TensorFlow SavedModel format to artifacts\prepare_base_model\base_model.h5
